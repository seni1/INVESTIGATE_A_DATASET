# %% [markdown]
# > **Tip**: Welcome to the Investigate a Dataset project! You will find tips in quoted sections like this to help organize your approach to your investigation. Before submitting your project, it will be a good idea to go back through your report and remove these sections to make the presentation of your work as tidy as possible. First things first, you might want to double-click this Markdown cell and change the title so that it reflects your dataset and investigation.
#
# # Project: Investigate a Dataset of mean years in school for men and women accross countries
#
# ## Table of Contents
# <ul>
# <li><a href="#intro">Introduction</a></li>
# <li><a href="#wrangling">Data Wrangling</a></li>
# <li><a href="#eda">Exploratory Data Analysis</a></li>
# <li><a href="#conclusions">Conclusions</a></li>
# </ul>

# %% [markdown]
# <a id='intro'></a>
# ## Introduction
#
# > **Tip**: In this section of the report, provide a brief introduction to the dataset you've selected for analysis. At the end of this section, describe the questions that you plan on exploring over the course of the report. Try to build your report around the analysis of at least one dependent variable and three independent variables.
# >
# >I've selected my dataset from: https://www.gapminder.org/data/
# >
# >I'm really interested in investigating the amount of education people acquire during their life time, and how different age groups amongst men and women compare in the levels of education over time.
# Therefore data that I chose represents values of mean years in school (including primary, secondary and higher tertiary education) for men and women in year segements of:
# >15 to 24; 25 to 34; 35 to 44 years; 45 to 54 years; 55 to 64 years and 65 plus years.
#
# >I intend to explore the following questions with this dataset:
#
# > ***1. What are noticeable trends and relationships in the dataset for Women?***
#
# > ***2. What are noticeable trends and relationships in the dataset for Men?***
#
# > ***3. Which countries we can identify with the highest levels of education for Women?***
#
# > ***4. Which countries we can identify with the highest levels of education for Men?***
#
# >

# %%
# Use this cell to set up import statements for all of the packages that you
#   plan to use.
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
# Remember to include a 'magic word' so that your visualizations are plotted
#   inline with the notebook. See this page for more:
#   http://ipython.readthedocs.io/en/stable/interactive/magics.html

# %% [markdown]
# <a id='wrangling'></a>
# ## Data Wrangling
#
# > **First step**: In this section of the report, I'm going to load data from csv files on the computer, checked for cleanliness, such as null or missing values, wrong datat formats or bad column names.  Then I will start performing methods to organize the data for exploration.
#
# ### General Properties

# %%
# Load your data and print out a few lines. Perform operations to inspect data
#   types and look for instances of missing or possibly errant data.

w_1524 = pd.read_csv('/Users/senkampro/Documents/DATA_SCIENCE/DAND/PROJECT_2 2/P2_REVIEW/home/mean_years_in_school_women_15_to_24_years.csv')
w_2534 = pd.read_csv('/Users/senkampro/Documents/DATA_SCIENCE/DAND/PROJECT_2 2/P2_REVIEW/home/mean_years_in_school_women_25_to_34_years.csv')
w_3544 = pd.read_csv('/Users/senkampro/Documents/DATA_SCIENCE/DAND/PROJECT_2 2/P2_REVIEW/home/mean_years_in_school_women_35_to_44_years.csv')
w_4554 = pd.read_csv('/Users/senkampro/Documents/DATA_SCIENCE/DAND/PROJECT_2 2/P2_REVIEW/home/mean_years_in_school_women_45_to_54_years.csv')
w_5564 = pd.read_csv('/Users/senkampro/Documents/DATA_SCIENCE/DAND/PROJECT_2 2/P2_REVIEW/home/mean_years_in_school_women_55_to_64_years.csv')
w_65 = pd.read_csv('/Users/senkampro/Documents/DATA_SCIENCE/DAND/PROJECT_2 2/P2_REVIEW/home/mean_years_in_school_women_65_plus_years.csv')

#Importing the Men's data from csv files
m_1524 = pd.read_csv('/Users/senkampro/Documents/DATA_SCIENCE/DAND/PROJECT_2 2/P2_REVIEW/home/mean_years_in_school_men_15_to_24_years.csv')
m_2534 = pd.read_csv('/Users/senkampro/Documents/DATA_SCIENCE/DAND/PROJECT_2 2/P2_REVIEW/home/mean_years_in_school_men_25_to_34_years.csv')
m_3544 = pd.read_csv('/Users/senkampro/Documents/DATA_SCIENCE/DAND/PROJECT_2 2/P2_REVIEW/home/mean_years_in_school_men_35_to_44_years.csv')
m_4554 = pd.read_csv('/Users/senkampro/Documents/DATA_SCIENCE/DAND/PROJECT_2 2/P2_REVIEW/home/mean_years_in_school_men_45_to_54_years.csv')
m_5564 = pd.read_csv('/Users/senkampro/Documents/DATA_SCIENCE/DAND/PROJECT_2 2/P2_REVIEW/home/mean_years_in_school_men_55_to_64_years.csv')
m_65 = pd.read_csv('/Users/senkampro/Documents/DATA_SCIENCE/DAND/PROJECT_2 2/P2_REVIEW/home/mean_years_in_school_men_55_to_64_years.csv')

# %% [markdown]
# > **Import complete**: Data files for Men and Women of different Age Groups have been imported. In this project I've adapted the following naming concept:
# w_1524 where w stands for category Women, 1524 stands for Age Group 15 to 24 years of age.  w_65 stands for Women 65 plus year of age.  Similar naming concept is applied to Men's data.
#
# > **Working with 12 datasets**: As you can see above, we've imported 12 different datasets related to a particlar Age Group of Men and Women. Since we're going to use all of them for our analysis we have to verify successful import and look for flaws in each and everyone of them.  So let's get started.
#
# ### Data Cleaning: I used the following methods to identify flaws and missing values in the datasets

# %%
def check(df):
#    """"Checking if the data import from csv was successful, 
#    also checking for missing values""""
    shape = df.shape
    null = df.isnull().sum()
    dups = df.info()
    return shape, null, dups

check(w_1524)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 187 entries, 0 to 186
# Data columns (total 47 columns):
# country    187 non-null object
# 1970       187 non-null float64
# 1971       187 non-null float64
# 1972       187 non-null float64
# 1973       187 non-null float64
# 1974       187 non-null float64
# 1975       187 non-null float64
# 1976       187 non-null float64
# 1977       187 non-null float64
# 1978       187 non-null float64
# 1979       187 non-null float64
# 1980       187 non-null float64
# 1981       187 non-null float64
# 1982       187 non-null float64
# 1983       187 non-null float64
# 1984       187 non-null float64
# 1985       187 non-null float64
# 1986       187 non-null float64
# 1987       187 non-null float64
# 1988       187 non-null float64
# 1989       187 non-null float64
# 1990       187 non-null float64
# 1991       187 non-null float64
# 1992       187 non-null float64
# 1993       187 non-null float64
# 1994       187 non-null float64
# ...

# %%
check(w_2534)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 187 entries, 0 to 186
# Data columns (total 47 columns):
# country    187 non-null object
# 1970       187 non-null float64
# 1971       187 non-null float64
# 1972       187 non-null float64
# 1973       187 non-null float64
# 1974       187 non-null float64
# 1975       187 non-null float64
# 1976       187 non-null float64
# 1977       187 non-null float64
# 1978       187 non-null float64
# 1979       187 non-null float64
# 1980       187 non-null float64
# 1981       187 non-null float64
# 1982       187 non-null float64
# 1983       187 non-null float64
# 1984       187 non-null float64
# 1985       187 non-null float64
# 1986       187 non-null float64
# 1987       187 non-null float64
# 1988       187 non-null float64
# 1989       187 non-null float64
# 1990       187 non-null float64
# 1991       187 non-null float64
# 1992       187 non-null float64
# 1993       187 non-null float64
# 1994       187 non-null float64
# ...

# %%
check(w_3544)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 187 entries, 0 to 186
# Data columns (total 47 columns):
# country    187 non-null object
# 1970       187 non-null float64
# 1971       187 non-null float64
# 1972       187 non-null float64
# 1973       187 non-null float64
# 1974       187 non-null float64
# 1975       187 non-null float64
# 1976       187 non-null float64
# 1977       187 non-null float64
# 1978       187 non-null float64
# 1979       187 non-null float64
# 1980       187 non-null float64
# 1981       187 non-null float64
# 1982       187 non-null float64
# 1983       187 non-null float64
# 1984       187 non-null float64
# 1985       187 non-null float64
# 1986       187 non-null float64
# 1987       187 non-null float64
# 1988       187 non-null float64
# 1989       187 non-null float64
# 1990       187 non-null float64
# 1991       187 non-null float64
# 1992       187 non-null float64
# 1993       187 non-null float64
# 1994       187 non-null float64
# ...

# %%
check(w_4554)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 187 entries, 0 to 186
# Data columns (total 47 columns):
# country    187 non-null object
# 1970       187 non-null float64
# 1971       187 non-null float64
# 1972       187 non-null float64
# 1973       187 non-null float64
# 1974       187 non-null float64
# 1975       187 non-null float64
# 1976       187 non-null float64
# 1977       187 non-null float64
# 1978       187 non-null float64
# 1979       187 non-null float64
# 1980       187 non-null float64
# 1981       187 non-null float64
# 1982       187 non-null float64
# 1983       187 non-null float64
# 1984       187 non-null float64
# 1985       187 non-null float64
# 1986       187 non-null float64
# 1987       187 non-null float64
# 1988       187 non-null float64
# 1989       187 non-null float64
# 1990       187 non-null float64
# 1991       187 non-null float64
# 1992       187 non-null float64
# 1993       187 non-null float64
# 1994       187 non-null float64
# ...

# %%
check(w_5564)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 187 entries, 0 to 186
# Data columns (total 47 columns):
# country    187 non-null object
# 1970       187 non-null float64
# 1971       187 non-null float64
# 1972       187 non-null float64
# 1973       187 non-null float64
# 1974       187 non-null float64
# 1975       187 non-null float64
# 1976       187 non-null float64
# 1977       187 non-null float64
# 1978       187 non-null float64
# 1979       187 non-null float64
# 1980       187 non-null float64
# 1981       187 non-null float64
# 1982       187 non-null float64
# 1983       187 non-null float64
# 1984       187 non-null float64
# 1985       187 non-null float64
# 1986       187 non-null float64
# 1987       187 non-null float64
# 1988       187 non-null float64
# 1989       187 non-null float64
# 1990       187 non-null float64
# 1991       187 non-null float64
# 1992       187 non-null float64
# 1993       187 non-null float64
# 1994       187 non-null float64
# ...

# %%
check(w_65)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 187 entries, 0 to 186
# Data columns (total 47 columns):
# country    187 non-null object
# 1970       187 non-null float64
# 1971       187 non-null float64
# 1972       187 non-null float64
# 1973       187 non-null float64
# 1974       187 non-null float64
# 1975       187 non-null float64
# 1976       187 non-null float64
# 1977       187 non-null float64
# 1978       187 non-null float64
# 1979       187 non-null float64
# 1980       187 non-null float64
# 1981       187 non-null float64
# 1982       187 non-null float64
# 1983       187 non-null float64
# 1984       187 non-null float64
# 1985       187 non-null float64
# 1986       187 non-null float64
# 1987       187 non-null float64
# 1988       187 non-null float64
# 1989       187 non-null float64
# 1990       187 non-null float64
# 1991       187 non-null float64
# 1992       187 non-null float64
# 1993       187 non-null float64
# 1994       187 non-null float64
# ...

# %% [markdown]
# ### Now we check the Men's datasets in the similar fashion

# %%
check(m_1524)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 187 entries, 0 to 186
# Data columns (total 47 columns):
# country    187 non-null object
# 1970       187 non-null float64
# 1971       187 non-null float64
# 1972       187 non-null float64
# 1973       187 non-null float64
# 1974       187 non-null float64
# 1975       187 non-null float64
# 1976       187 non-null float64
# 1977       187 non-null float64
# 1978       187 non-null float64
# 1979       187 non-null float64
# 1980       187 non-null float64
# 1981       187 non-null float64
# 1982       187 non-null float64
# 1983       187 non-null float64
# 1984       187 non-null float64
# 1985       187 non-null float64
# 1986       187 non-null float64
# 1987       187 non-null float64
# 1988       187 non-null float64
# 1989       187 non-null float64
# 1990       187 non-null float64
# 1991       187 non-null float64
# 1992       187 non-null float64
# 1993       187 non-null float64
# 1994       187 non-null float64
# ...

# %%
check(m_2534)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 187 entries, 0 to 186
# Data columns (total 47 columns):
# country    187 non-null object
# 1970       187 non-null float64
# 1971       187 non-null float64
# 1972       187 non-null float64
# 1973       187 non-null float64
# 1974       187 non-null float64
# 1975       187 non-null float64
# 1976       187 non-null float64
# 1977       187 non-null float64
# 1978       187 non-null float64
# 1979       187 non-null float64
# 1980       187 non-null float64
# 1981       187 non-null float64
# 1982       187 non-null float64
# 1983       187 non-null float64
# 1984       187 non-null float64
# 1985       187 non-null float64
# 1986       187 non-null float64
# 1987       187 non-null float64
# 1988       187 non-null float64
# 1989       187 non-null float64
# 1990       187 non-null float64
# 1991       187 non-null float64
# 1992       187 non-null float64
# 1993       187 non-null float64
# 1994       187 non-null float64
# ...

# %%
check(m_3544)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 187 entries, 0 to 186
# Data columns (total 47 columns):
# country    187 non-null object
# 1970       187 non-null float64
# 1971       187 non-null float64
# 1972       187 non-null float64
# 1973       187 non-null float64
# 1974       187 non-null float64
# 1975       187 non-null float64
# 1976       187 non-null float64
# 1977       187 non-null float64
# 1978       187 non-null float64
# 1979       187 non-null float64
# 1980       187 non-null float64
# 1981       187 non-null float64
# 1982       187 non-null float64
# 1983       187 non-null float64
# 1984       187 non-null float64
# 1985       187 non-null float64
# 1986       187 non-null float64
# 1987       187 non-null float64
# 1988       187 non-null float64
# 1989       187 non-null float64
# 1990       187 non-null float64
# 1991       187 non-null float64
# 1992       187 non-null float64
# 1993       187 non-null float64
# 1994       187 non-null float64
# ...

# %%
check(m_4554)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 187 entries, 0 to 186
# Data columns (total 47 columns):
# country    187 non-null object
# 1970       187 non-null float64
# 1971       187 non-null float64
# 1972       187 non-null float64
# 1973       187 non-null float64
# 1974       187 non-null float64
# 1975       187 non-null float64
# 1976       187 non-null float64
# 1977       187 non-null float64
# 1978       187 non-null float64
# 1979       187 non-null float64
# 1980       187 non-null float64
# 1981       187 non-null float64
# 1982       187 non-null float64
# 1983       187 non-null float64
# 1984       187 non-null float64
# 1985       187 non-null float64
# 1986       187 non-null float64
# 1987       187 non-null float64
# 1988       187 non-null float64
# 1989       187 non-null float64
# 1990       187 non-null float64
# 1991       187 non-null float64
# 1992       187 non-null float64
# 1993       187 non-null float64
# 1994       187 non-null float64
# ...

# %%
check(m_5564)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 187 entries, 0 to 186
# Data columns (total 47 columns):
# country    187 non-null object
# 1970       187 non-null float64
# 1971       187 non-null float64
# 1972       187 non-null float64
# 1973       187 non-null float64
# 1974       187 non-null float64
# 1975       187 non-null float64
# 1976       187 non-null float64
# 1977       187 non-null float64
# 1978       187 non-null float64
# 1979       187 non-null float64
# 1980       187 non-null float64
# 1981       187 non-null float64
# 1982       187 non-null float64
# 1983       187 non-null float64
# 1984       187 non-null float64
# 1985       187 non-null float64
# 1986       187 non-null float64
# 1987       187 non-null float64
# 1988       187 non-null float64
# 1989       187 non-null float64
# 1990       187 non-null float64
# 1991       187 non-null float64
# 1992       187 non-null float64
# 1993       187 non-null float64
# 1994       187 non-null float64
# ...

# %%
check(m_65)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 187 entries, 0 to 186
# Data columns (total 47 columns):
# country    187 non-null object
# 1970       187 non-null float64
# 1971       187 non-null float64
# 1972       187 non-null float64
# 1973       187 non-null float64
# 1974       187 non-null float64
# 1975       187 non-null float64
# 1976       187 non-null float64
# 1977       187 non-null float64
# 1978       187 non-null float64
# 1979       187 non-null float64
# 1980       187 non-null float64
# 1981       187 non-null float64
# 1982       187 non-null float64
# 1983       187 non-null float64
# 1984       187 non-null float64
# 1985       187 non-null float64
# 1986       187 non-null float64
# 1987       187 non-null float64
# 1988       187 non-null float64
# 1989       187 non-null float64
# 1990       187 non-null float64
# 1991       187 non-null float64
# 1992       187 non-null float64
# 1993       187 non-null float64
# 1994       187 non-null float64
# ...

# %%
m_65.head()
# Out:
#        country  1970  1971  1972  1973  1974  1975  1976  1977  1978  ...  \
# 0  Afghanistan  0.75  0.77  0.79  0.82  0.84  0.86  0.89  0.91  0.94  ...
# 1      Albania  4.89  5.00  5.10  5.21  5.32  5.43  5.54  5.65  5.77  ...
# 2      Algeria  0.45  0.47  0.48  0.50  0.51  0.53  0.55  0.56  0.58  ...
# 3      Andorra  5.76  5.88  5.99  6.11  6.23  6.35  6.48  6.60  6.72  ...
# 4       Angola  1.14  1.17  1.20  1.23  1.27  1.30  1.34  1.37  1.41  ...
#
#     2006   2007   2008   2009   2010   2011   2012   2013   2014   2015
# 0   2.01   2.06   2.12   2.17   2.23   2.29   2.35   2.41   2.47   2.53
# 1   9.51   9.65   9.80   9.94  10.10  10.20  10.40  10.50  10.70  10.80
# 2   1.53   1.58   1.63   1.67   1.72   1.77   1.82   1.87   1.92   1.98
# 3  10.50  10.70  10.80  10.90  11.10  11.20  11.40  11.50  11.60  11.80
# 4   2.91   2.99   3.06   3.13   3.21   3.29   3.37   3.45   3.53   3.61
#
# [5 rows x 47 columns]

# %% [markdown]
# > **Clean, complete datasets for Men**: The results above show us that all the datasets for Men are clean, complete and a ready for further analysis and data manipulation.
#
# > **Findings**: We didn't find any missing values, duplicated values, incorrect datatypes in the Men's datasets. The data has a simple organization pattern: Columns represent years, 1970 to 2015; Rows represent entries for a single counrty, 187 of them
#
# ### Data Cleaning (None required)

# %% [markdown]
# <a id='eda'></a>
# ## Exploratory Data Analysis
#
# > **Exploration Stage**: We are ready to move on to exploration. Compute statistics and create visualizations with the goal of addressing the research questions that is posed in the Introduction section. We start with one Age Group for Women at a time.
#
# ### Research Question 1: What are noticeable trends and relationships in the dataset for Women?

# %%
#Exploring the datasets through visualization
w_1524.mean().plot(kind='bar', figsize=(13,6));

# %%
#Exploring the datasets through visualization
w_2534.mean().plot(kind='bar', figsize=(13,6));

# %%
#Exploring the datasets through visualization
w_3544.mean().plot(kind='bar', figsize=(13,6));

# %%
#Exploring the datasets through visualization
w_4554.mean().plot(kind='bar', figsize=(13, 6));

# %%
#Exploring the datasets through visualization
w_5564.mean().plot(kind='bar', figsize=(13,6));

# %%
#Exploring the datasets through visualization
w_65.mean().plot(kind='bar', figsize=(13,6));

# %% [markdown]
# > **Observation**: Similar rising trend. All the Age Groups for Women (15-24; 25-34; 35-44; 45-54; 55-64 and 65 plus) all show a continous increase in the mean number of years of education over the years.
#
# > **Conclusion**: In every Age Group, Women acquire more education compared with previous years.  This means that every year, on average, all over the world, Women study more and more.

# %% [markdown]
# ### Now I will do a bit of data wrangling to be able to aggregate datasets and simplify calculations

# %%
#Investigating columns names
w_1524.columns
# Out:
# Index(['country', '1970', '1971', '1972', '1973', '1974', '1975', '1976',
#        '1977', '1978', '1979', '1980', '1981', '1982', '1983', '1984', '1985',
#        '1986', '1987', '1988', '1989', '1990', '1991', '1992', '1993', '1994',
#        '1995', '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003',
#        '2004', '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012',
#        '2013', '2014', '2015'],
#       dtype='object')

# %%
#Investigating columns names
w_2534.columns
# Out:
# Index(['country', '1970', '1971', '1972', '1973', '1974', '1975', '1976',
#        '1977', '1978', '1979', '1980', '1981', '1982', '1983', '1984', '1985',
#        '1986', '1987', '1988', '1989', '1990', '1991', '1992', '1993', '1994',
#        '1995', '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003',
#        '2004', '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012',
#        '2013', '2014', '2015'],
#       dtype='object')

# %%
#Investigating columns names
w_3544.columns
# Out:
# Index(['country', '1970', '1971', '1972', '1973', '1974', '1975', '1976',
#        '1977', '1978', '1979', '1980', '1981', '1982', '1983', '1984', '1985',
#        '1986', '1987', '1988', '1989', '1990', '1991', '1992', '1993', '1994',
#        '1995', '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003',
#        '2004', '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012',
#        '2013', '2014', '2015'],
#       dtype='object')

# %%
#Investigating columns names
w_4554.columns
# Out:
# Index(['country', '1970', '1971', '1972', '1973', '1974', '1975', '1976',
#        '1977', '1978', '1979', '1980', '1981', '1982', '1983', '1984', '1985',
#        '1986', '1987', '1988', '1989', '1990', '1991', '1992', '1993', '1994',
#        '1995', '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003',
#        '2004', '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012',
#        '2013', '2014', '2015'],
#       dtype='object')

# %%
#Investigating columns names
w_5564.columns
# Out:
# Index(['country', '1970', '1971', '1972', '1973', '1974', '1975', '1976',
#        '1977', '1978', '1979', '1980', '1981', '1982', '1983', '1984', '1985',
#        '1986', '1987', '1988', '1989', '1990', '1991', '1992', '1993', '1994',
#        '1995', '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003',
#        '2004', '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012',
#        '2013', '2014', '2015'],
#       dtype='object')

# %%
#Investigating columns names
w_65.columns
# Out:
# Index(['country', '1970', '1971', '1972', '1973', '1974', '1975', '1976',
#        '1977', '1978', '1979', '1980', '1981', '1982', '1983', '1984', '1985',
#        '1986', '1987', '1988', '1989', '1990', '1991', '1992', '1993', '1994',
#        '1995', '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003',
#        '2004', '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012',
#        '2013', '2014', '2015'],
#       dtype='object')

# %% [markdown]
# > **Observation**: Since the data in all sets goes from 1970 to 2015, for easier analysis I will aggregate it into 10year - decade periods, drop the data from 1970 to 1974 in all datasets, and will analyze data from 1975 to 2015 in 10year segments.

# %%
#First I discover the index of the columns that I'm going to work with
print(w_1524.columns.get_loc('1974'))
print(w_1524.columns.get_loc('2015'))
#First I discover the index of the columns that I'm going to work with
print(w_2534.columns.get_loc('1974'))
print(w_2534.columns.get_loc('2015'))
#First I discover the index of the columns that I'm going to work with
print(w_3544.columns.get_loc('1974'))
print(w_3544.columns.get_loc('2015'))
#First I discover the index of the columns that I'm going to work with
print(w_4554.columns.get_loc('1974'))
print(w_4554.columns.get_loc('2015'))
#First I discover the index of the columns that I'm going to work with
print(w_5564.columns.get_loc('1974'))
print(w_5564.columns.get_loc('2015'))
#First I discover the index of the columns that I'm going to work with
print(w_65.columns.get_loc('1974'))
print(w_65.columns.get_loc('2015'))
# Out:
# 5
# 46
# 5
# 46
# 5
# 46
# 5
# 46
# 5
# 46
# 5
# 46

# %% [markdown]
# > **Approach**: First I create the decade columns using mean values.

# %%
#Calculating the mean and creating columns for 10year periods
def decades(dx):
    
    dx['80s'] = dx.iloc[:, 6:17].mean(axis=1)
    dx['90s'] = dx.iloc[:, 16:27].mean(axis=1)
    dx['00s'] = dx.iloc[:, 26:37].mean(axis=1)
    dx['10s'] = dx.iloc[:, 36:47].mean(axis=1)
    
decades(w_1524)
decades(w_2534)
decades(w_3544)
decades(w_4554)
decades(w_5564)
decades(w_65)

# %%
w_1524.columns
# Out:
# Index(['country', '1970', '1971', '1972', '1973', '1974', '1975', '1976',
#        '1977', '1978', '1979', '1980', '1981', '1982', '1983', '1984', '1985',
#        '1986', '1987', '1988', '1989', '1990', '1991', '1992', '1993', '1994',
#        '1995', '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003',
#        '2004', '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012',
#        '2013', '2014', '2015', '80s', '90s', '00s', '10s'],
#       dtype='object')

# %%
w_65.columns
# Out:
# Index(['country', '1970', '1971', '1972', '1973', '1974', '1975', '1976',
#        '1977', '1978', '1979', '1980', '1981', '1982', '1983', '1984', '1985',
#        '1986', '1987', '1988', '1989', '1990', '1991', '1992', '1993', '1994',
#        '1995', '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003',
#        '2004', '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012',
#        '2013', '2014', '2015', '80s', '90s', '00s', '10s'],
#       dtype='object')

# %% [markdown]
# > **Approach**: Now that we've aggregated the necessary years into decades, we need to drop all the columns, except the last 4.

# %%
#Dropping the columns for Women
w_1524 = w_1524.drop(w_1524.iloc[:, 1:47], axis=1)
w_2534 = w_2534.drop(w_2534.iloc[:, 1:47], axis=1)
w_3544 = w_3544.drop(w_3544.iloc[:, 1:47], axis=1)
w_4554 = w_4554.drop(w_4554.iloc[:, 1:47], axis=1)
w_5564 = w_5564.drop(w_5564.iloc[:, 1:47], axis=1)
w_65 = w_65.drop(w_65.iloc[:, 1:47], axis=1)

# %%
#Checkig for column names
print(w_1524.columns)
print(w_2534.columns)
print(w_3544.columns)
print(w_4554.columns)
print(w_5564.columns)
print(w_65.columns)
# Out:
# Index(['country', '80s', '90s', '00s', '10s'], dtype='object')
# Index(['country', '80s', '90s', '00s', '10s'], dtype='object')
# Index(['country', '80s', '90s', '00s', '10s'], dtype='object')
# Index(['country', '80s', '90s', '00s', '10s'], dtype='object')
# Index(['country', '80s', '90s', '00s', '10s'], dtype='object')
# Index(['country', '80s', '90s', '00s', '10s'], dtype='object')

# %% [markdown]
# > **Approach**: Now that we have the desired columns left in the dataset, I'm going to rename the columns by addidng suffix that stands for a particular Age Group.

# %%
#Renaming columns by adding the suffix to specific columns
#I use this method to add suffix to specific columns:

##new_names = [(i,i+'_x') for i in df.iloc[:, 2:].columns.values]
##df.rename(columns = dict(new_names), inplace=True)
new_names = [(i, i+'_w1524') for i in w_1524.iloc[:, 1:].columns.values]
w_1524.rename(columns = dict(new_names), inplace=True)

new_names = [(i, i+'_w2534') for i in w_2534.iloc[:, 1:].columns.values]
w_2534.rename(columns = dict(new_names), inplace=True)

new_names = [(i, i+'_w3544') for i in w_3544.iloc[:, 1:].columns.values]
w_3544.rename(columns = dict(new_names), inplace=True)

new_names = [(i, i+'_w4554') for i in w_4554.iloc[:, 1:].columns.values]
w_4554.rename(columns = dict(new_names), inplace=True)

new_names = [(i, i+'_w5564') for i in w_5564.iloc[:, 1:].columns.values]
w_5564.rename(columns = dict(new_names), inplace=True)

new_names = [(i, i+'_w65') for i in w_65.iloc[:, 1:].columns.values]
w_65.rename(columns = dict(new_names), inplace=True)

# %%
#Renaming columns by adding the suffix to specific columns
#I use this method to add suffix to specific columns:

##new_names = [(i,i+'_x') for i in df.iloc[:, 2:].columns.values]
##df.rename(columns = dict(new_names), inplace=True)

def rename(dr):
    new_names = [(i, i+'_w1524') for i in dr.iloc[:, 1:].columns.values]
    dr.rename(columns = dict(new_names), inplace=True)

rename(w_1524)
rename(w_2534)
rename(w_3544)
rename(w_4554)
rename(w_5564)
rename(w_65)

# %%
#Checkig for new column names with suffixes
print(w_1524.columns)
print(w_2534.columns)
print(w_3544.columns)
print(w_4554.columns)
print(w_5564.columns)
print(w_65.columns)
# Out:
# Index(['country', '80s_w1524', '90s_w1524', '00s_w1524', '10s_w1524'], dtype='object')
# Index(['country', '80s_w1524', '90s_w1524', '00s_w1524', '10s_w1524'], dtype='object')
# Index(['country', '80s_w1524', '90s_w1524', '00s_w1524', '10s_w1524'], dtype='object')
# Index(['country', '80s_w1524', '90s_w1524', '00s_w1524', '10s_w1524'], dtype='object')
# Index(['country', '80s_w1524', '90s_w1524', '00s_w1524', '10s_w1524'], dtype='object')
# Index(['country', '80s_w1524', '90s_w1524', '00s_w1524', '10s_w1524'], dtype='object')

# %% [markdown]
# > **Approach**: Now that we have distinguished the decades by respective Age Group suffixes, we can merge the datasets to be able to visualize the trends and relationships from a more wholistic prespective.

# %%
#Now we're going to merge and concatinate the DFs
#merged_df = DF2.merge(DF1, how = 'inner', on = ['date', 'hours'])

w_all = w_65.merge(w_5564, how = 'inner', on = ['country'])
w_all = w_all.merge(w_4554, how = 'inner', on = ['country'])
w_all = w_all.merge(w_3544, how = 'inner', on = ['country'])
w_all = w_all.merge(w_2534, how = 'inner', on = ['country'])
w_all = w_all.merge(w_1524, how = 'inner', on = ['country'])
w_all.columns
# Out:
# Index(['country', '80s_w65', '90s_w65', '00s_w65', '10s_w65', '80s_w5564',
#        '90s_w5564', '00s_w5564', '10s_w5564', '80s_w4554', '90s_w4554',
#        '00s_w4554', '10s_w4554', '80s_w3544', '90s_w3544', '00s_w3544',
#        '10s_w3544', '80s_w2534', '90s_w2534', '00s_w2534', '10s_w2534',
#        '80s_w1524', '90s_w1524', '00s_w1524', '10s_w1524'],
#       dtype='object')

# %% [markdown]
# > #### Now I'm going to plot the age groups of women with respect to decades against each other.

# %%
#Now I'm going to plot the age groups of women with respect to decades against each other
w_all.mean().plot(kind='bar', figsize=(13,7));
w_all.hist(figsize=(30,22));

# %% [markdown]
# > **Observation**: The DataFrame above clearly shows that the mean amount of years of education rises as the Age Group gets younger.  And that is true for all decades. 15-24 and 25-34 (the youngest) have more mean years of education compared to the Age Groups: 35-44, 45-54, 55-64 and 65plus respectively.
# Each one of the Age Groups displays a higher number of mean years of education compared to its older counterpart. This way 35-44 has more years than 45-54, 45-54 more years than 55-64, and 55-64 more years than 65plus.
# Histograms for decades 80s, 90s show a right scew for Age Groups: 45-54, 55-64 and 65 plus.  It means that there were few women with many years of educations for those decades in those Age Groups.  Decades 00s and 10s, show a left scew for Age Groups: 15-24 and 25-34, indicating that majority of women had more years of education.  Interesting to note Group 25-34 in the 10s (most recent decade).  Eventhough it's mean years of education is slightlty less, than group 15-24, the histograms shows several modes to the higher end of axis signaling that group 25-34 is actively studying.
#
# > **Conclusion**: Within every Age Group, we notice a rising trend, with respect to decades. It shows that every following decade women acquire more education in all examined Age Groups.  This rising trend is also true when we compare the Age Groups to one another.  The younger the Age Group, the more years of acquired education.  Yet the Age Groups 15-24 and 25-34 display almost similar mean values with a slight visible edge in favor of 15-24 Age Group.  Therefore, this conclusion is limited, because more current data is needed to prove that the trend exists today.

# %% [markdown]
# #### Going to extract plot and examine the data for "10s" decade

# %%
#Using 'iloc' and 'startswith' commands to extract the desired columns for ananysis
w_10 = w_all.iloc[:, w_all.columns.str.startswith('10')]
print(w_10.describe())
w_10.mean().plot(kind='bar', figsize=(6,4));
w_10.hist(figsize=(10,8));
# Out:
#           10s_w65   10s_w5564   10s_w4554   10s_w3544   10s_w2534   10s_w1524
# count  187.000000  187.000000  187.000000  187.000000  187.000000  187.000000
# mean     4.568760    5.884866    7.140778    8.334531    9.311998    9.578036
# std      3.821587    4.189933    4.291428    4.159564    3.924702    3.315910
# min      0.034545    0.116364    0.312727    0.624545    0.834545    1.537273
# 25%      0.893636    1.872273    3.212273    4.920455    6.146364    7.013182
# 50%      4.046364    5.714545    7.211818    8.788182   10.032727   10.442727
# 75%      7.691818    9.404545   10.899545   12.136364   12.640909   12.100000
# max     13.263636   14.090909   14.536364   15.054545   15.109091   15.490909

# %% [markdown]
# > **Observation**: The histogram 10s_w1524 and 10s_w2534 clearly show that more women in the Age Group 25-34 have over 14 yeas of mean education compared to the 15-24 Age Group, but 15-24 AG has highest number of mean years of education.
#
# > **Conclusion**: It looks like the youngest 15-24 Age Group is setting the rising dynamics for more mean years of education for the other groups.  Learning more at younger age, results in more years of education for women of all ages if they continue studying.  However, factors such as emancipation and liberalization of women in traditional countries may have an effect of the above data in waysd which I can't compute.

# %% [markdown]
# ### Research Question 2: What are noticeable trends and relationships in the dataset for Men?

# %%
#Exploring the datasets through visualization
m_1524.mean().plot(kind='bar', figsize=(13,6));

# %%
#Exploring the datasets through visualization
m_2534.mean().plot(kind='bar', figsize=(13,6));

# %%
#Exploring the datasets through visualization
m_3544.mean().plot(kind='bar', figsize=(13,6));

# %%
#Exploring the datasets through visualization
m_4554.mean().plot(kind='bar', figsize=(13,6));

# %%
#Exploring the datasets through visualization
m_5564.mean().plot(kind='bar', figsize=(13,6));

# %%
#Exploring the datasets through visualization
m_65.mean().plot(kind='bar', figsize=(13,6));

# %% [markdown]
# > **Observation**: Similar rising trend over the years just as we saw with Women. All the Age Groups for Men (15-24; 25-34; 35-44; 45-54; 55-64 and 65 plus) all show a continous increase in the mean number of years of education over the years.
#
# > **Conclusion**: In every Age Group, Men acquire more education compared with previous years.  The plot shows that every year, on average, all over the world, Men study more and more.

# %% [markdown]
# ### Now I will do a bit of data wrangling to be able to aggregate datasets and simplify calculations

# %% [markdown]
# > **Observation**: Since the data in all sets goes from 1970 to 2015, for easier analysis I will aggregate it into 10year - decade periods, drop the data from 1970 to 1974 in all datasets, and will analyze data from 1975 to 2015 in 10year segments.

# %%
#First I discover the index of the columns that I'm going to work with
print(m_1524.columns.get_loc('1974'))
print(m_1524.columns.get_loc('2015'))
#First I discover the index of the columns that I'm going to work with
print(m_2534.columns.get_loc('1974'))
print(m_2534.columns.get_loc('2015'))
#First I discover the index of the columns that I'm going to work with
print(m_3544.columns.get_loc('1974'))
print(m_3544.columns.get_loc('2015'))
#First I discover the index of the columns that I'm going to work with
print(m_4554.columns.get_loc('1974'))
print(m_4554.columns.get_loc('2015'))
#First I discover the index of the columns that I'm going to work with
print(m_5564.columns.get_loc('1974'))
print(m_5564.columns.get_loc('2015'))
#First I discover the index of the columns that I'm going to work with
print(m_65.columns.get_loc('1974'))
print(m_65.columns.get_loc('2015'))
# Out:
# 5
# 46
# 5
# 46
# 5
# 46
# 5
# 46
# 5
# 46
# 5
# 46

# %% [markdown]
# > **Approach**: First I create the decade columns using mean values.

# %%
#Calculating the mean and creating columns for 10year periods
m_1524['80s'] = m_1524.iloc[:, 6:17].mean(axis=1)
m_1524['90s'] = m_1524.iloc[:, 16:27].mean(axis=1)
m_1524['00s'] = m_1524.iloc[:, 26:37].mean(axis=1)
m_1524['10s'] = m_1524.iloc[:, 36:47].mean(axis=1)
#Calculating the mean and creating columns for 10year periods
m_2534['80s'] = m_2534.iloc[:, 6:17].mean(axis=1)
m_2534['90s'] = m_2534.iloc[:, 16:27].mean(axis=1)
m_2534['00s'] = m_2534.iloc[:, 26:37].mean(axis=1)
m_2534['10s'] = m_2534.iloc[:, 36:47].mean(axis=1)
#Calculating the mean and creating columns for 10year periods
m_3544['80s'] = m_3544.iloc[:, 6:17].mean(axis=1)
m_3544['90s'] = m_3544.iloc[:, 16:27].mean(axis=1)
m_3544['00s'] = m_3544.iloc[:, 26:37].mean(axis=1)
m_3544['10s'] = m_3544.iloc[:, 36:47].mean(axis=1)
#Calculating the mean and creating columns for 10year periods
m_4554['80s'] = m_4554.iloc[:, 6:17].mean(axis=1)
m_4554['90s'] = m_4554.iloc[:, 16:27].mean(axis=1)
m_4554['00s'] = m_4554.iloc[:, 26:37].mean(axis=1)
m_4554['10s'] = m_4554.iloc[:, 36:47].mean(axis=1)
#Calculating the mean and creating columns for 10year periods
m_5564['80s'] = m_5564.iloc[:, 6:17].mean(axis=1)
m_5564['90s'] = m_5564.iloc[:, 16:27].mean(axis=1)
m_5564['00s'] = m_5564.iloc[:, 26:37].mean(axis=1)
m_5564['10s'] = m_5564.iloc[:, 36:47].mean(axis=1)
#Calculating the mean and creating columns for 10year periods
m_65['80s'] = m_65.iloc[:, 6:17].mean(axis=1)
m_65['90s'] = m_65.iloc[:, 16:27].mean(axis=1)
m_65['00s'] = m_65.iloc[:, 26:37].mean(axis=1)
m_65['10s'] = m_65.iloc[:, 36:47].mean(axis=1)

# %%
#Checking for the newly created column name in DF
print(m_1524.iloc[:,47].name)
print(m_2534.iloc[:,47].name)
print(m_3544.iloc[:,47].name)
print(m_4554.iloc[:,47].name)
print(m_5564.iloc[:,47].name)
print(m_65.iloc[:,47].name)
# Out:
# 80s
# 80s
# 80s
# 80s
# 80s
# 80s

# %%
#Checkig for column names
print(m_1524.columns)
print(m_2534.columns)
print(m_3544.columns)
print(m_4554.columns)
print(m_5564.columns)
print(m_65.columns)
# Out:
# Index(['country', '1970', '1971', '1972', '1973', '1974', '1975', '1976',
#        '1977', '1978', '1979', '1980', '1981', '1982', '1983', '1984', '1985',
#        '1986', '1987', '1988', '1989', '1990', '1991', '1992', '1993', '1994',
#        '1995', '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003',
#        '2004', '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012',
#        '2013', '2014', '2015', '80s', '90s', '00s', '10s'],
#       dtype='object')
# Index(['country', '1970', '1971', '1972', '1973', '1974', '1975', '1976',
#        '1977', '1978', '1979', '1980', '1981', '1982', '1983', '1984', '1985',
#        '1986', '1987', '1988', '1989', '1990', '1991', '1992', '1993', '1994',
#        '1995', '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003',
#        '2004', '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012',
#        '2013', '2014', '2015', '80s', '90s', '00s', '10s'],
#       dtype='object')
# ...

# %% [markdown]
# > **Approach**: Now that we've aggregated the necessary years into decades, we need to drop all the columns, except the last 4.

# %%
#Dropping the columns for Men
m_1524 = m_1524.drop(m_1524.iloc[:, 1:47], axis=1)
m_2534 = m_2534.drop(m_2534.iloc[:, 1:47], axis=1)
m_3544 = m_3544.drop(m_3544.iloc[:, 1:47], axis=1)
m_4554 = m_4554.drop(m_4554.iloc[:, 1:47], axis=1)
m_5564 = m_5564.drop(m_5564.iloc[:, 1:47], axis=1)
m_65 = m_65.drop(m_65.iloc[:, 1:47], axis=1)

# %%
#Checkig for column names
print(m_1524.columns)
print(m_2534.columns)
print(m_3544.columns)
print(m_4554.columns)
print(m_5564.columns)
print(m_65.columns)
# Out:
# Index(['country', '80s', '90s', '00s', '10s'], dtype='object')
# Index(['country', '80s', '90s', '00s', '10s'], dtype='object')
# Index(['country', '80s', '90s', '00s', '10s'], dtype='object')
# Index(['country', '80s', '90s', '00s', '10s'], dtype='object')
# Index(['country', '80s', '90s', '00s', '10s'], dtype='object')
# Index(['country', '80s', '90s', '00s', '10s'], dtype='object')

# %% [markdown]
# > **Approach**: Now that we have the desired columns left in the dataset, I'm going to rename the columns by addidng suffix that stands for a particular Age Group.

# %%
#Renaming columns by adding the suffix to specific columns
#I use this method to add suffix to specific columns:

##new_names = [(i,i+'_x') for i in df.iloc[:, 2:].columns.values]
##df.rename(columns = dict(new_names), inplace=True)
new_names = [(i, i+'_m1524') for i in m_1524.iloc[:, 1:].columns.values]
m_1524.rename(columns = dict(new_names), inplace=True)

new_names = [(i, i+'_m2534') for i in m_2534.iloc[:, 1:].columns.values]
m_2534.rename(columns = dict(new_names), inplace=True)

new_names = [(i, i+'_m3544') for i in m_3544.iloc[:, 1:].columns.values]
m_3544.rename(columns = dict(new_names), inplace=True)

new_names = [(i, i+'_m4554') for i in m_4554.iloc[:, 1:].columns.values]
m_4554.rename(columns = dict(new_names), inplace=True)

new_names = [(i, i+'_m5564') for i in m_5564.iloc[:, 1:].columns.values]
m_5564.rename(columns = dict(new_names), inplace=True)

new_names = [(i, i+'_m65') for i in m_65.iloc[:, 1:].columns.values]
m_65.rename(columns = dict(new_names), inplace=True)

# %%
#Checkig for new column names with suffixes
print(m_1524.columns)
print(m_2534.columns)
print(m_3544.columns)
print(m_4554.columns)
print(m_5564.columns)
print(m_65.columns)
# Out:
# Index(['country', '80s_m1524', '90s_m1524', '00s_m1524', '10s_m1524'], dtype='object')
# Index(['country', '80s_m2534', '90s_m2534', '00s_m2534', '10s_m2534'], dtype='object')
# Index(['country', '80s_m3544', '90s_m3544', '00s_m3544', '10s_m3544'], dtype='object')
# Index(['country', '80s_m4554', '90s_m4554', '00s_m4554', '10s_m4554'], dtype='object')
# Index(['country', '80s_m5564', '90s_m5564', '00s_m5564', '10s_m5564'], dtype='object')
# Index(['country', '80s_m65', '90s_m65', '00s_m65', '10s_m65'], dtype='object')

# %% [markdown]
# > **Approach**: Now that we have distinguished the decades by respective Age Group suffixes, we can merge the datasets to be able to visualize the trends and relationships from a more wholistic prespective.

# %%
#Now we're going to merge and concatinate the DFs
#merged_df = DF2.merge(DF1, how = 'inner', on = ['date', 'hours'])

m_all = m_65.merge(m_5564, how = 'inner', on = ['country'])
m_all = m_all.merge(m_4554, how = 'inner', on = ['country'])
m_all = m_all.merge(m_3544, how = 'inner', on = ['country'])
m_all = m_all.merge(m_2534, how = 'inner', on = ['country'])
m_all = m_all.merge(m_1524, how = 'inner', on = ['country'])
m_all.columns
# Out:
# Index(['country', '80s_m65', '90s_m65', '00s_m65', '10s_m65', '80s_m5564',
#        '90s_m5564', '00s_m5564', '10s_m5564', '80s_m4554', '90s_m4554',
#        '00s_m4554', '10s_m4554', '80s_m3544', '90s_m3544', '00s_m3544',
#        '10s_m3544', '80s_m2534', '90s_m2534', '00s_m2534', '10s_m2534',
#        '80s_m1524', '90s_m1524', '00s_m1524', '10s_m1524'],
#       dtype='object')

# %% [markdown]
# > #### Now I'm going to plot the age groups of Men with respect to decades against each other.

# %%
#Now I'm going to plot the age groups of Men with respect to decades against each other
m_all.mean().plot(kind='bar', figsize=(13,7));
m_all.hist(figsize=(30,22));

# %% [markdown]
# > **Observation**: Just as with the Women's dataset the plot above clearly shows that the mean amount of years of education rises as the Age Group gets younger.  And that is true for all decades. 15-24 and 25-34 (the youngest) have more mean years of education compared to the Age Groups: 35-44, 45-54, 55-64 and 65plus respectively.
# Each one of the Age Groups displays a higher number of mean years of education compared to its older counterpart. Except for 25-34.  For Men this AG is the highest in the mean number of years of education across all decadeds. Even higher than the AG 15-24, which is the highest in Women. As for the other AGs, the picture is similar to Women: 35-44 has more years than 45-54, 45-54 more years than 55-64, and 55-64 more years than 65plus.
# Unlike for Women, for Men the histograms for decades 80s and 90s don't show such a profound "right scew", yet the "right scew" can still be seen especially for older generations.
#
# > **Conclusion**: Within every Age Group, we notice a rising trend, with respect to decades. It shows that every following decade Men acquire more education in all examined Age Groups.  This rising trend is also true when we compare the Age Groups to one another.  The younger the Age Group, the more years of acquired education, except for AG 25-34.  We can conclude that amongst Men, just like Women, the education is on the rise over the years and the momentum is highest with the younger generations.  However, AG 15-24 is lagging behind 25-34, it could mean that Men are more zealous in stydying after 25.  To be fair the mean values between these AGs in Women are also very close.  I would like to assume that now both Men and Women continue to study more after 25, compared to previous decades, and that's why this AG displays high values in both datasets. But we don't have the most recent data to substantiate further.

# %% [markdown]
# ### Research Question 3: Which countries we can identify with the highest mean amount of years of education for Women?

# %% [markdown]
# >**Approach**: I'm going to identify the countries where many Women have more than or equal to mean 11yrs. of education

# %%
#Creating a new column "mean" and calculating the mean for all rows 'countries'
#df['mean'] = df.mean(axis=1)

#Then using the query function to display the countries with more than or equal to mean 11yr of education
w_all['mean'] = w_all.mean(axis=1)
w_all.query('mean >= 11')['country']
# Out:
# 30             Canada
# 46            Denmark
# 80             Israel
# 83              Japan
# 119       New Zealand
# 124            Norway
# 177    United Kingdom
# 178     United States
# Name: country, dtype: object

# %% [markdown]
# > **Observation**: Canada, Denmark, Israel, Japan, New Zealand, Norway, United Kingdom and United States have the Women with the mean amount of years of education equal to or more than 11yrs.
#
# > **Conclusion**: The above countries have robust economies, powerful democratic institutions and high standard of living.  I can conclude that economic, political, and traditional values play a big role in access and ecouragement in education for Women.  With that said, the list of contries could've been different if we analyzed only the recent years.

# %% [markdown]
# ### Research Question 4: Which countries we can identify with the highest mean amount of years of education for Men?

# %% [markdown]
# >**Approach**: I'm going to identify the countries where many Men have more than or equal to mean 11yrs. of education

# %%
#Creating a new column "mean" and calculating the mean for all rows 'countries'
#df['mean'] = df.mean(axis=1)

#Then using the query function to display the countries with more than or equal to mean 11yr of education
m_all['mean'] = m_all.mean(axis=1)
m_all.query('mean >= 11')['country']
# Out:
# 8           Australia
# 30             Canada
# 45     Czech Republic
# 46            Denmark
# 74            Iceland
# 80             Israel
# 83              Japan
# 118       Netherlands
# 119       New Zealand
# 124            Norway
# 162       Switzerland
# 177    United Kingdom
# 178     United States
# Name: country, dtype: object

# %% [markdown]
# > **Observation**: Australia, Canada, Czech Republic, Denmark, Iceland, Israel, Japan, Netherlands, New Zealand, Norway, Switzerland, United Kingdom and United States have the Men with the mean amount of years of education equal to or more than 11yrs.
#
# > **Conclusion**: The above countries also have robust economies, powerful democratic institutions and high standard of living.  I can conclude that just as for Women, economic, political, and traditional values of a country play a big role in access and ecouragement in education.  With that said, the list of contries could've been different if we analyzed only the recent years.

# %% [markdown]
# ### Gonna start from  adding the Men's and Women's datasets!!!

# %%
#First I'm gonna drop the columns for women...
w_1524 = w_1524.drop(w_1524.iloc[:, 1:47], axis=1)
w_2534 = w_2534.drop(w_2534.iloc[:, 1:47], axis=1)
w_3544 = w_3544.drop(w_3544.iloc[:, 1:47], axis=1)
w_4554 = w_4554.drop(w_4554.iloc[:, 1:47], axis=1)
w_5564 = w_5564.drop(w_5564.iloc[:, 1:47], axis=1)
w_65 = w_65.drop(w_65.iloc[:, 1:47], axis=1)

#Then drop the columns for men... 
m_1524 = m_1524.drop(m_1524.iloc[:, 1:47], axis=1)
m_2534 = m_2534.drop(m_2534.iloc[:, 1:47], axis=1)
m_3544 = m_3544.drop(m_3544.iloc[:, 1:47], axis=1)
m_4554 = m_4554.drop(m_4554.iloc[:, 1:47], axis=1)
m_5564 = m_5564.drop(m_5564.iloc[:, 1:47], axis=1)
m_65 = m_65.drop(m_65.iloc[:, 1:47], axis=1)

# %%
w_1524.head(3)
# Out:
#        country
# 0  Afghanistan
# 1      Albania
# 2      Algeria

# %%
m_1524.head(3)
# Out:
#        country
# 0  Afghanistan
# 1      Albania
# 2      Algeria

# %%
#I'm going to add the columns in both datasets
mw_1524 = w_1524.add(m_1524, fill_value=0)
#Need to drop a column from DF
mw_1524 = mw_1524.drop(['country'], axis=1)
#Adding a new column
mw_1524['15_24'] = '15-24'
#Grouping by Age Group
mw_1524 = mw_1524.groupby('15_24').mean()
# Out:
# ---------------------------------------------------------------------------
# DataError                                 Traceback (most recent call last)
# <ipython-input-78-90ce5265c45f> in <module>
#       6 mw_1524['15_24'] = '15_24'
#       7 #Grouping by Age Group
# ----> 8 mw_1524 = mw_1524.groupby('15_24').mean()
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/groupby/groupby.py in mean(self, *args, **kwargs)
#    1130         nv.validate_groupby_func('mean', args, kwargs, ['numeric_only'])
#    1131         try:
# -> 1132             return self._cython_agg_general('mean', **kwargs)
#    1133         except GroupByError:
#    1134             raise
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/groupby/generic.py in _cython_agg_general(self, how, alt, numeric_only, min_count)
#      68                             min_count=-1):
#      69         new_items, new_blocks = self._cython_agg_blocks(
# ...

# %%
mw_2534 = w_2534.add(m_2534, fill_value=0)
mw_2534 = mw_2534.drop(['country'], axis=1)
mw_2534['25_34'] = '25-34'
mw_2534 = mw_2534.groupby('25_34').mean()

# %%
#Now I'm going to append the 2 Age Groups according to decades
#result = df1.append([df2, df3])
mw = mw_1524.append([mw_2534])
mw.head(3)

# %%
#I'm going to add the columns in both datasets
mw_3544 = w_3544.add(m_3544, fill_value=0)
#Need to drop a column from DF
mw_3544 = mw_3544.drop(['country'], axis=1)
#Adding a new column
mw_3544['35_44'] = '35-44'
#Grouping by Age Group
mw_3544 = mw_3544.groupby('35_44').mean()
mw_3544.head(3)

# %%
#I'm going to add the columns in both datasets
mw_4554 = w_4554.add(m_4554, fill_value=0)
#Need to drop a column from DF
mw_4554 = mw_4554.drop(['country'], axis=1)
#Adding a new column
mw_4554['45_54'] = '45-54'
#Grouping by Age Group
mw_4554 = mw_4554.groupby('45_54').mean()
mw_4554.head(3)

# %%
#I'm going to add the columns in both datasets
mw_5564 = w_5564.add(m_5564, fill_value=0)
#Need to drop a column from DF
mw_5564 = mw_5564.drop(['country'], axis=1)
#Adding a new column
mw_5564['55_64'] = '55-64'
#Grouping by Age Group
mw_5564 = mw_5564.groupby('55_64').mean()
mw_5564.head(3)

# %%
#I'm going to add the columns in both datasets
mw_65 = w_65.add(m_65, fill_value=0)
#Need to drop a column from DF
mw_65 = mw_65.drop(['country'], axis=1)
#Adding a new column
mw_65['65'] = '65'
#Grouping by Age Group
mw_65 = mw_65.groupby('65').mean()
mw_65.head(3)

# %%
#Now I'm going to append the 2 Age Groups according to decades
#result = df1.append([df2, df3])
mw = mw.append([mw_3544, mw_4554, mw_5564, mw_65])

# %%
mw.plot(kind='bar', figsize=(12,8));

# %% [markdown]
# ### From the plot above it is obvious that older Age Groups have less mean years of education accross decades than the younger ones.

# %%
mw.head(10)
